# %%
from app_dataset import DataBuilder
from app_hyperparam import HyperparameterOptimization
import pandas as pd 
from app_training import Training
from torch import nn 
from app_utils import *

# %% [markdown]
# Mejores hiperparámetros: {'lr': 0.00033507116131146765, 'weight_decay': 0.00019220347864886488, 'activation_function': 'PReLU'} A 0.5714985020458

# %%
df = pd.read_csv("./data/poi_train.csv", sep=';', decimal='.')
train_loader, val_loader, num_features_tab=DataBuilder(dataframe=df).build()

trainer = Training(
            model='A',
            activation_function=nn.PReLU(),
            lr=0.00023507116131146765,
            weight_d=0.00019220347864886488,
            num_features_tab=num_features_tab,
            num_epoch=40,
            train_loader=train_loader,
            val_loader=val_loader
        )
trainer.run()
# Out:
# d:\ejecutables\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# [INFO]: Entrenando red neuronal...
# Training: 100%|██████████| 40/40 [05:06<00:00,  7.67s/epoch, train_accuracy=0.808, train_loss=0.555, val_accuracy=0.71, val_loss=0.641]

# %%
display_loss_and_accuracy(trainer.train_losses, trainer.val_losses, trainer.train_accuracy, trainer.val_accuracy,40)

# %%
df = pd.read_csv("./data/poi_train.csv", sep=';', decimal='.')
train_loader, val_loader, num_features_tab=DataBuilder(dataframe=df).build()
hyperopt = HyperparameterOptimization(train_loader=train_loader,val_loader=val_loader,num_features_tab=num_features_tab,name_study='hp_TransferLearning_12',model='B')
study = hyperopt.optimize()
print("Mejores hiperparámetros:", study.best_params)
# Out:
# [I 2025-01-21 23:45:57,366] A new study created in RDB with name: hp_TransferLearning_12
# [INFO]: Entrenando red neuronal...
# Training: 100%|██████████| 35/35 [04:39<00:00,  8.00s/epoch, train_accuracy=0.796, train_loss=1.03, val_accuracy=0.783, val_loss=1.02]
# [I 2025-01-21 23:50:37,768] Trial 0 finished with value: 1.016186997294426 and parameters: {'lr': 0.0001504724774221882, 'weight_decay': 0.0005173061728228964, 'activation_function': 'PReLU'}. Best is trial 0 with value: 1.016186997294426.
# [INFO]: Entrenando red neuronal...
# Training: 100%|██████████| 35/35 [04:34<00:00,  7.83s/epoch, train_accuracy=0.853, train_loss=0.423, val_accuracy=0.811, val_loss=0.516]
# [I 2025-01-21 23:55:12,275] Trial 1 finished with value: 0.5162819009274244 and parameters: {'lr': 0.0024302631984354475, 'weight_decay': 1.009602302752236e-05, 'activation_function': 'PReLU'}. Best is trial 1 with value: 0.5162819009274244.
# [INFO]: Entrenando red neuronal...
# ...

# %%
df = pd.read_csv("./data/poi_train.csv", sep=';', decimal='.')
train_loader, val_loader, num_features_tab=DataBuilder(dataframe=df).build()

trainer = Training(
            model='B',
            activation_function=nn.PReLU(),
            lr=0.0024302631984354475,
            weight_d=1.009602302752236e-05,
            num_features_tab=num_features_tab,
            num_epoch=35,
            train_loader=train_loader,
            val_loader=val_loader
        )
trainer.run()
# Out:
# [INFO]: Entrenando red neuronal...
# Training: 100%|██████████| 35/35 [04:40<00:00,  8.02s/epoch, train_accuracy=0.847, train_loss=0.431, val_accuracy=0.757, val_loss=0.59]

# %%
display_loss_and_accuracy(trainer.train_losses, trainer.val_losses, trainer.train_accuracy, trainer.val_accuracy,35)

# %%
df = pd.read_csv("./data/poi_train.csv", sep=';', decimal='.')
train_loader, val_loader, num_features_tab=DataBuilder(dataframe=df).build()

trainer = Training(
            model='B',
            activation_function=nn.PReLU(),
            lr=0.00037421180148082,
            weight_d=0.0009619658746356874,
            num_features_tab=num_features_tab,
            num_epoch=35,
            train_loader=train_loader,
            val_loader=val_loader
        )
trainer.run()
# Out:
# [INFO]: Entrenando red neuronal...
# Training: 100%|██████████| 35/35 [04:40<00:00,  8.02s/epoch, train_accuracy=0.839, train_loss=0.568, val_accuracy=0.779, val_loss=0.619]

# %%
display_loss_and_accuracy(trainer.train_losses, trainer.val_losses, trainer.train_accuracy, trainer.val_accuracy,35)

# %%
import optuna

db_path = "sqlite:///optuna_study.db"
study_name = "hp_TransferLearning_12"

storage = optuna.storages.RDBStorage(url=db_path)
study = optuna.load_study(study_name=study_name, storage=storage)

optuna.visualization.plot_param_importances(study)

# %%
optuna.visualization.plot_parallel_coordinate(study)
